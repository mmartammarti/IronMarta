# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# ### json response

# %%
# install json on python if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe

# %%
data=pd.DataFrame.from_dict(results)

# %%
data
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response=requests.get('https://api.github.com/users/siandav/events/public')
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': '17143200148',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7510824416,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e6ba7d390d0c21955480d27d5db8d32fc12cfa13',
#    'before': 'a27a9e1be7e17974d4b9d51868286edf02f894f6',
#    'commits': [{'sha': 'e6ba7d390d0c21955480d27d5db8d32fc12cfa13',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/e6ba7d390d0c21955480d27d5db8d32fc12cfa13'}]},
#   'public': True,
#   'created_at': '2021-07-13T12:00:17Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17142967176',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7510713314,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a27a9e1be7e17974d4b9d51868286edf02f894f6',
#    'before': '0caff9d6eadf728aad8cb9a6e86e0ba563c9f28c',
#    'commits': [{'sha': 'a27a9e1be7e17974d4b9d51868286edf02f894f6',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/a27a9e1be7e17974d4b9d51868286edf02f894f6'}]},
#   'public': True,
#   'created_at': '2021-07-13T11:44:39Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17101618605',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 336077917,
#    'name': 'student-IH-labs-and-stuff/BER-DAFT-MAR21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21'},
#   'payload': {'push_id': 7489207232,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '28d3a53f3f017702854f2989c305f7e28d8f17f7',
#    'before': '327ef166f61253c20e1ddbd35662fb55fd1f04e6',
#    'commits': [{'sha': '28d3a53f3f017702854f2989c305f7e28d8f17f7',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update RFM_casestudy.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21/commits/28d3a53f3f017702854f2989c305f7e28d8f17f7'}]},
#   'public': True,
#   'created_at': '2021-07-09T12:07:23Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17101488063',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 336077917,
#    'name': 'student-IH-labs-and-stuff/BER-DAFT-MAR21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21'},
#   'payload': {'push_id': 7489141426,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '327ef166f61253c20e1ddbd35662fb55fd1f04e6',
#    'before': 'b5bf4834025c9a5eadd31e422991ce94775ba740',
#    'commits': [{'sha': '327ef166f61253c20e1ddbd35662fb55fd1f04e6',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update RFM_casestudy.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21/commits/327ef166f61253c20e1ddbd35662fb55fd1f04e6'}]},
#   'public': True,
#   'created_at': '2021-07-09T11:56:33Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17101481142',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 336077917,
#    'name': 'student-IH-labs-and-stuff/BER-DAFT-MAR21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21'},
#   'payload': {'push_id': 7489138034,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b5bf4834025c9a5eadd31e422991ce94775ba740',
#    'before': '192415f4cd0176c16cb6f55aab988e41a95481d5',
#    'commits': [{'sha': 'b5bf4834025c9a5eadd31e422991ce94775ba740',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update RFM_casestudy.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BER-DAFT-MAR21/commits/b5bf4834025c9a5eadd31e422991ce94775ba740'}]},
#   'public': True,
#   'created_at': '2021-07-09T11:55:56Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17098560889',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7487707451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0caff9d6eadf728aad8cb9a6e86e0ba563c9f28c',
#    'before': '834fecef75d7fa10d82dbc37d77c7df039beada5',
#    'commits': [{'sha': '0caff9d6eadf728aad8cb9a6e86e0ba563c9f28c',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/0caff9d6eadf728aad8cb9a6e86e0ba563c9f28c'}]},
#   'public': True,
#   'created_at': '2021-07-09T08:00:06Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17098550367',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7487702456,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '834fecef75d7fa10d82dbc37d77c7df039beada5',
#    'before': '7b063e8e2a8d41ddaec44bef67cfd52f16ae0da6',
#    'commits': [{'sha': '834fecef75d7fa10d82dbc37d77c7df039beada5',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/834fecef75d7fa10d82dbc37d77c7df039beada5'}]},
#   'public': True,
#   'created_at': '2021-07-09T07:59:13Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17073479989',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7475550137,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7b063e8e2a8d41ddaec44bef67cfd52f16ae0da6',
#    'before': 'd0cbb9fcd58c20883282f7782af49e245a7e3d74',
#    'commits': [{'sha': '7b063e8e2a8d41ddaec44bef67cfd52f16ae0da6',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update RFM_lab.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/7b063e8e2a8d41ddaec44bef67cfd52f16ae0da6'}]},
#   'public': True,
#   'created_at': '2021-07-07T15:50:53Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17043586926',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7460922995,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd0cbb9fcd58c20883282f7782af49e245a7e3d74',
#    'before': '0c204b99738f41dec31d4a8cb47c7262640e25ad',
#    'commits': [{'sha': 'd0cbb9fcd58c20883282f7782af49e245a7e3d74',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/d0cbb9fcd58c20883282f7782af49e245a7e3d74'}]},
#   'public': True,
#   'created_at': '2021-07-05T16:47:48Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17043576309',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7460917492,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0c204b99738f41dec31d4a8cb47c7262640e25ad',
#    'before': '61c93c17e183bd7e4d16ccf4243efecac77f5edf',
#    'commits': [{'sha': '0c204b99738f41dec31d4a8cb47c7262640e25ad',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/0c204b99738f41dec31d4a8cb47c7262640e25ad'}]},
#   'public': True,
#   'created_at': '2021-07-05T16:46:38Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17043563484',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7460910727,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '61c93c17e183bd7e4d16ccf4243efecac77f5edf',
#    'before': '051688c41cc171db77fbb37010ee2ceedabf12e5',
#    'commits': [{'sha': '61c93c17e183bd7e4d16ccf4243efecac77f5edf',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/61c93c17e183bd7e4d16ccf4243efecac77f5edf'}]},
#   'public': True,
#   'created_at': '2021-07-05T16:45:08Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17043557357',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7460907494,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '051688c41cc171db77fbb37010ee2ceedabf12e5',
#    'before': '78babfe0a38f2aace6b40e990f2503ecb864707e',
#    'commits': [{'sha': '051688c41cc171db77fbb37010ee2ceedabf12e5',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/051688c41cc171db77fbb37010ee2ceedabf12e5'}]},
#   'public': True,
#   'created_at': '2021-07-05T16:44:27Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17043548222',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7460902779,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '78babfe0a38f2aace6b40e990f2503ecb864707e',
#    'before': '1fe8bfb6375df593ee94de7d0f26f5c6962f02c0',
#    'commits': [{'sha': '78babfe0a38f2aace6b40e990f2503ecb864707e',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create Facebook_movement.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/78babfe0a38f2aace6b40e990f2503ecb864707e'}]},
#   'public': True,
#   'created_at': '2021-07-05T16:43:24Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17041051551',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7459665379,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1fe8bfb6375df593ee94de7d0f26f5c6962f02c0',
#    'before': 'ae7dde404309f8edbe9c2ae6ac46940110e5106b',
#    'commits': [{'sha': '1fe8bfb6375df593ee94de7d0f26f5c6962f02c0',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/1fe8bfb6375df593ee94de7d0f26f5c6962f02c0'}]},
#   'public': True,
#   'created_at': '2021-07-05T13:28:19Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17041041816',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7459660817,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ae7dde404309f8edbe9c2ae6ac46940110e5106b',
#    'before': '4b54bf1f67ca68132cd34a5133240adddb14c7d0',
#    'commits': [{'sha': 'ae7dde404309f8edbe9c2ae6ac46940110e5106b',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/ae7dde404309f8edbe9c2ae6ac46940110e5106b'}]},
#   'public': True,
#   'created_at': '2021-07-05T13:27:42Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17003958215',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7440053688,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4b54bf1f67ca68132cd34a5133240adddb14c7d0',
#    'before': 'e5a2ffff52c4ecf267e8e9f335b8e638f9cfa7da',
#    'commits': [{'sha': '4b54bf1f67ca68132cd34a5133240adddb14c7d0',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/4b54bf1f67ca68132cd34a5133240adddb14c7d0'}]},
#   'public': True,
#   'created_at': '2021-07-01T15:34:55Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '17003948887',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7440049122,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e5a2ffff52c4ecf267e8e9f335b8e638f9cfa7da',
#    'before': '4550a1099521119d7cabc00c602201d038ed0067',
#    'commits': [{'sha': 'e5a2ffff52c4ecf267e8e9f335b8e638f9cfa7da',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/e5a2ffff52c4ecf267e8e9f335b8e638f9cfa7da'}]},
#   'public': True,
#   'created_at': '2021-07-01T15:34:19Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16954122060',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7416200828,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4550a1099521119d7cabc00c602201d038ed0067',
#    'before': '67096375885c8a09c5a04ec530628addbcef40e3',
#    'commits': [{'sha': '4550a1099521119d7cabc00c602201d038ed0067',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/4550a1099521119d7cabc00c602201d038ed0067'}]},
#   'public': True,
#   'created_at': '2021-06-28T16:15:32Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16952147903',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7415272473,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '67096375885c8a09c5a04ec530628addbcef40e3',
#    'before': '98702d38d2daf1015bfb328ea32f8ad2b1a9066d',
#    'commits': [{'sha': '67096375885c8a09c5a04ec530628addbcef40e3',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/67096375885c8a09c5a04ec530628addbcef40e3'}]},
#   'public': True,
#   'created_at': '2021-06-28T14:13:16Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16946117130',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7412397516,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '98702d38d2daf1015bfb328ea32f8ad2b1a9066d',
#    'before': 'b395f1b73277c76edd60a4155ae0abe4b10c5efd',
#    'commits': [{'sha': '98702d38d2daf1015bfb328ea32f8ad2b1a9066d',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/98702d38d2daf1015bfb328ea32f8ad2b1a9066d'}]},
#   'public': True,
#   'created_at': '2021-06-28T07:03:40Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16922960359',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7399412833,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b395f1b73277c76edd60a4155ae0abe4b10c5efd',
#    'before': 'c718acdbf5f51fff62619db5f2e63e7ca621904e',
#    'commits': [{'sha': 'b395f1b73277c76edd60a4155ae0abe4b10c5efd',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/b395f1b73277c76edd60a4155ae0abe4b10c5efd'}]},
#   'public': True,
#   'created_at': '2021-06-25T08:47:56Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16922862960',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7399364763,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c718acdbf5f51fff62619db5f2e63e7ca621904e',
#    'before': '8a576c71899483232f0a2d652685b791ca58a32d',
#    'commits': [{'sha': 'c718acdbf5f51fff62619db5f2e63e7ca621904e',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/c718acdbf5f51fff62619db5f2e63e7ca621904e'}]},
#   'public': True,
#   'created_at': '2021-06-25T08:40:13Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16922851041',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7399358866,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8a576c71899483232f0a2d652685b791ca58a32d',
#    'before': 'f0ecd8b33b6155ccf07a2024fcc92adf0e67c723',
#    'commits': [{'sha': '8a576c71899483232f0a2d652685b791ca58a32d',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/8a576c71899483232f0a2d652685b791ca58a32d'}]},
#   'public': True,
#   'created_at': '2021-06-25T08:39:15Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16922777681',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7399321486,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f0ecd8b33b6155ccf07a2024fcc92adf0e67c723',
#    'before': 'e3a23d3d9fedeb30ab2da59ae845cfec639a4ba1',
#    'commits': [{'sha': 'f0ecd8b33b6155ccf07a2024fcc92adf0e67c723',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/f0ecd8b33b6155ccf07a2024fcc92adf0e67c723'}]},
#   'public': True,
#   'created_at': '2021-06-25T08:33:27Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16922752966',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7399309191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e3a23d3d9fedeb30ab2da59ae845cfec639a4ba1',
#    'before': 'd75f1fd6e00c4f8cd94de86fa9664a6b816afe74',
#    'commits': [{'sha': 'e3a23d3d9fedeb30ab2da59ae845cfec639a4ba1',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create solutions.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/e3a23d3d9fedeb30ab2da59ae845cfec639a4ba1'}]},
#   'public': True,
#   'created_at': '2021-06-25T08:31:26Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16907011180',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7391585281,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd75f1fd6e00c4f8cd94de86fa9664a6b816afe74',
#    'before': '4bdd4e0221d5408344b69ef56452b98f2807b33f',
#    'commits': [{'sha': 'd75f1fd6e00c4f8cd94de86fa9664a6b816afe74',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/d75f1fd6e00c4f8cd94de86fa9664a6b816afe74'}]},
#   'public': True,
#   'created_at': '2021-06-24T08:29:44Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16896813580',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7386436351,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4bdd4e0221d5408344b69ef56452b98f2807b33f',
#    'before': '0fbea532181ed3c23144e91783ab820b8574a0a7',
#    'commits': [{'sha': '4bdd4e0221d5408344b69ef56452b98f2807b33f',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/4bdd4e0221d5408344b69ef56452b98f2807b33f'}]},
#   'public': True,
#   'created_at': '2021-06-23T15:36:11Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16896772316',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7386416708,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0fbea532181ed3c23144e91783ab820b8574a0a7',
#    'before': 'd9ccdf8b5195ab2a28a2f87e0bb9e8fd14826b99',
#    'commits': [{'sha': '0fbea532181ed3c23144e91783ab820b8574a0a7',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/0fbea532181ed3c23144e91783ab820b8574a0a7'}]},
#   'public': True,
#   'created_at': '2021-06-23T15:33:39Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16896704839',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7386384972,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd9ccdf8b5195ab2a28a2f87e0bb9e8fd14826b99',
#    'before': '31a5a0b257fb358af3ef8098f85e36c9eab6c65e',
#    'commits': [{'sha': 'd9ccdf8b5195ab2a28a2f87e0bb9e8fd14826b99',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/d9ccdf8b5195ab2a28a2f87e0bb9e8fd14826b99'}]},
#   'public': True,
#   'created_at': '2021-06-23T15:29:33Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '16896695836',
#   'type': 'PushEvent',
#   'actor': {'id': 71644535,
#    'login': 'siandav',
#    'display_login': 'siandav',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siandav',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71644535?'},
#   'repo': {'id': 368110379,
#    'name': 'student-IH-labs-and-stuff/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7386380770,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '31a5a0b257fb358af3ef8098f85e36c9eab6c65e',
#    'before': '5e569670a146e0e295c82ca8c099f7770cfb6529',
#    'commits': [{'sha': '31a5a0b257fb358af3ef8098f85e36c9eab6c65e',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Data_Thieves.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BEES-DAFT-MAY21/commits/31a5a0b257fb358af3ef8098f85e36c9eab6c65e'}]},
#   'public': True,
#   'created_at': '2021-06-23T15:29:00Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}}]

# %%
#turn the json into a Data Frame 
pd.DataFrame(response.json())
# Out:
#              id       type                                              actor  \
# 0   17143200148  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 1   17142967176  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 2   17101618605  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 3   17101488063  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 4   17101481142  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 5   17098560889  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 6   17098550367  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 7   17073479989  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 8   17043586926  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 9   17043576309  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 10  17043563484  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 11  17043557357  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 12  17043548222  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 13  17041051551  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 14  17041041816  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 15  17003958215  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 16  17003948887  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 17  16954122060  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 18  16952147903  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 19  16946117130  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 20  16922960359  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 21  16922862960  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 22  16922851041  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 23  16922777681  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 24  16922752966  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 25  16907011180  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 26  16896813580  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 27  16896772316  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 28  16896704839  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
# 29  16896695836  PushEvent  {'id': 71644535, 'login': 'siandav', 'display_...
#
#                                                  repo  \
# 0   {'id': 368110379, 'name': 'student-IH-labs-and...
# 1   {'id': 368110379, 'name': 'student-IH-labs-and...
# 2   {'id': 336077917, 'name': 'student-IH-labs-and...
# 3   {'id': 336077917, 'name': 'student-IH-labs-and...
# 4   {'id': 336077917, 'name': 'student-IH-labs-and...
# 5   {'id': 368110379, 'name': 'student-IH-labs-and...
# 6   {'id': 368110379, 'name': 'student-IH-labs-and...
# 7   {'id': 368110379, 'name': 'student-IH-labs-and...
# 8   {'id': 368110379, 'name': 'student-IH-labs-and...
# 9   {'id': 368110379, 'name': 'student-IH-labs-and...
# 10  {'id': 368110379, 'name': 'student-IH-labs-and...
# 11  {'id': 368110379, 'name': 'student-IH-labs-and...
# 12  {'id': 368110379, 'name': 'student-IH-labs-and...
# 13  {'id': 368110379, 'name': 'student-IH-labs-and...
# 14  {'id': 368110379, 'name': 'student-IH-labs-and...
# 15  {'id': 368110379, 'name': 'student-IH-labs-and...
# 16  {'id': 368110379, 'name': 'student-IH-labs-and...
# 17  {'id': 368110379, 'name': 'student-IH-labs-and...
# 18  {'id': 368110379, 'name': 'student-IH-labs-and...
# 19  {'id': 368110379, 'name': 'student-IH-labs-and...
# 20  {'id': 368110379, 'name': 'student-IH-labs-and...
# 21  {'id': 368110379, 'name': 'student-IH-labs-and...
# 22  {'id': 368110379, 'name': 'student-IH-labs-and...
# 23  {'id': 368110379, 'name': 'student-IH-labs-and...
# 24  {'id': 368110379, 'name': 'student-IH-labs-and...
# 25  {'id': 368110379, 'name': 'student-IH-labs-and...
# 26  {'id': 368110379, 'name': 'student-IH-labs-and...
# 27  {'id': 368110379, 'name': 'student-IH-labs-and...
# 28  {'id': 368110379, 'name': 'student-IH-labs-and...
# 29  {'id': 368110379, 'name': 'student-IH-labs-and...
#
#                                               payload  public  \
# 0   {'push_id': 7510824416, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 7510713314, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 7489207232, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 7489141426, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 7489138034, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 7487707451, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 7487702456, 'size': 1, 'distinct_s...    True
# 7   {'push_id': 7475550137, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 7460922995, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 7460917492, 'size': 1, 'distinct_s...    True
# 10  {'push_id': 7460910727, 'size': 1, 'distinct_s...    True
# 11  {'push_id': 7460907494, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 7460902779, 'size': 1, 'distinct_s...    True
# 13  {'push_id': 7459665379, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 7459660817, 'size': 1, 'distinct_s...    True
# 15  {'push_id': 7440053688, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 7440049122, 'size': 1, 'distinct_s...    True
# 17  {'push_id': 7416200828, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 7415272473, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 7412397516, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 7399412833, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 7399364763, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 7399358866, 'size': 1, 'distinct_s...    True
# 23  {'push_id': 7399321486, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 7399309191, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 7391585281, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 7386436351, 'size': 1, 'distinct_s...    True
# 27  {'push_id': 7386416708, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 7386384972, 'size': 1, 'distinct_s...    True
# 29  {'push_id': 7386380770, 'size': 1, 'distinct_s...    True
#
#               created_at                                                org
# 0   2021-07-13T12:00:17Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 1   2021-07-13T11:44:39Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 2   2021-07-09T12:07:23Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 3   2021-07-09T11:56:33Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 4   2021-07-09T11:55:56Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 5   2021-07-09T08:00:06Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 6   2021-07-09T07:59:13Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 7   2021-07-07T15:50:53Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 8   2021-07-05T16:47:48Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 9   2021-07-05T16:46:38Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 10  2021-07-05T16:45:08Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 11  2021-07-05T16:44:27Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 12  2021-07-05T16:43:24Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 13  2021-07-05T13:28:19Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 14  2021-07-05T13:27:42Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 15  2021-07-01T15:34:55Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 16  2021-07-01T15:34:19Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 17  2021-06-28T16:15:32Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 18  2021-06-28T14:13:16Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 19  2021-06-28T07:03:40Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 20  2021-06-25T08:47:56Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 21  2021-06-25T08:40:13Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 22  2021-06-25T08:39:15Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 23  2021-06-25T08:33:27Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 24  2021-06-25T08:31:26Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 25  2021-06-24T08:29:44Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 26  2021-06-23T15:36:11Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 27  2021-06-23T15:33:39Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 28  2021-06-23T15:29:33Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 29  2021-06-23T15:29:00Z  {'id': 72746426, 'login': 'student-IH-labs-and...

# %%
#unpack the json using  pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id       type  public            created_at  actor.id  \
# 0   17143200148  PushEvent    True  2021-07-13T12:00:17Z  71644535
# 1   17142967176  PushEvent    True  2021-07-13T11:44:39Z  71644535
# 2   17101618605  PushEvent    True  2021-07-09T12:07:23Z  71644535
# 3   17101488063  PushEvent    True  2021-07-09T11:56:33Z  71644535
# 4   17101481142  PushEvent    True  2021-07-09T11:55:56Z  71644535
# 5   17098560889  PushEvent    True  2021-07-09T08:00:06Z  71644535
# 6   17098550367  PushEvent    True  2021-07-09T07:59:13Z  71644535
# 7   17073479989  PushEvent    True  2021-07-07T15:50:53Z  71644535
# 8   17043586926  PushEvent    True  2021-07-05T16:47:48Z  71644535
# 9   17043576309  PushEvent    True  2021-07-05T16:46:38Z  71644535
# 10  17043563484  PushEvent    True  2021-07-05T16:45:08Z  71644535
# 11  17043557357  PushEvent    True  2021-07-05T16:44:27Z  71644535
# 12  17043548222  PushEvent    True  2021-07-05T16:43:24Z  71644535
# 13  17041051551  PushEvent    True  2021-07-05T13:28:19Z  71644535
# 14  17041041816  PushEvent    True  2021-07-05T13:27:42Z  71644535
# 15  17003958215  PushEvent    True  2021-07-01T15:34:55Z  71644535
# 16  17003948887  PushEvent    True  2021-07-01T15:34:19Z  71644535
# 17  16954122060  PushEvent    True  2021-06-28T16:15:32Z  71644535
# 18  16952147903  PushEvent    True  2021-06-28T14:13:16Z  71644535
# 19  16946117130  PushEvent    True  2021-06-28T07:03:40Z  71644535
# 20  16922960359  PushEvent    True  2021-06-25T08:47:56Z  71644535
# 21  16922862960  PushEvent    True  2021-06-25T08:40:13Z  71644535
# 22  16922851041  PushEvent    True  2021-06-25T08:39:15Z  71644535
# 23  16922777681  PushEvent    True  2021-06-25T08:33:27Z  71644535
# 24  16922752966  PushEvent    True  2021-06-25T08:31:26Z  71644535
# 25  16907011180  PushEvent    True  2021-06-24T08:29:44Z  71644535
# 26  16896813580  PushEvent    True  2021-06-23T15:36:11Z  71644535
# 27  16896772316  PushEvent    True  2021-06-23T15:33:39Z  71644535
# 28  16896704839  PushEvent    True  2021-06-23T15:29:33Z  71644535
# 29  16896695836  PushEvent    True  2021-06-23T15:29:00Z  71644535
#
#    actor.login actor.display_login actor.gravatar_id  \
# 0      siandav             siandav
# 1      siandav             siandav
# 2      siandav             siandav
# 3      siandav             siandav
# 4      siandav             siandav
# 5      siandav             siandav
# 6      siandav             siandav
# 7      siandav             siandav
# 8      siandav             siandav
# 9      siandav             siandav
# 10     siandav             siandav
# 11     siandav             siandav
# 12     siandav             siandav
# 13     siandav             siandav
# 14     siandav             siandav
# 15     siandav             siandav
# 16     siandav             siandav
# 17     siandav             siandav
# 18     siandav             siandav
# 19     siandav             siandav
# 20     siandav             siandav
# 21     siandav             siandav
# 22     siandav             siandav
# 23     siandav             siandav
# 24     siandav             siandav
# 25     siandav             siandav
# 26     siandav             siandav
# 27     siandav             siandav
# 28     siandav             siandav
# 29     siandav             siandav
#
#                                actor.url  \
# 0   https://api.github.com/users/siandav
# 1   https://api.github.com/users/siandav
# 2   https://api.github.com/users/siandav
# 3   https://api.github.com/users/siandav
# 4   https://api.github.com/users/siandav
# 5   https://api.github.com/users/siandav
# 6   https://api.github.com/users/siandav
# 7   https://api.github.com/users/siandav
# 8   https://api.github.com/users/siandav
# 9   https://api.github.com/users/siandav
# 10  https://api.github.com/users/siandav
# 11  https://api.github.com/users/siandav
# 12  https://api.github.com/users/siandav
# 13  https://api.github.com/users/siandav
# 14  https://api.github.com/users/siandav
# 15  https://api.github.com/users/siandav
# 16  https://api.github.com/users/siandav
# 17  https://api.github.com/users/siandav
# 18  https://api.github.com/users/siandav
# 19  https://api.github.com/users/siandav
# 20  https://api.github.com/users/siandav
# 21  https://api.github.com/users/siandav
# 22  https://api.github.com/users/siandav
# 23  https://api.github.com/users/siandav
# 24  https://api.github.com/users/siandav
# 25  https://api.github.com/users/siandav
# 26  https://api.github.com/users/siandav
# 27  https://api.github.com/users/siandav
# 28  https://api.github.com/users/siandav
# 29  https://api.github.com/users/siandav
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/71644535?  ...
# 1   https://avatars.githubusercontent.com/u/71644535?  ...
# 2   https://avatars.githubusercontent.com/u/71644535?  ...
# 3   https://avatars.githubusercontent.com/u/71644535?  ...
# 4   https://avatars.githubusercontent.com/u/71644535?  ...
# 5   https://avatars.githubusercontent.com/u/71644535?  ...
# 6   https://avatars.githubusercontent.com/u/71644535?  ...
# 7   https://avatars.githubusercontent.com/u/71644535?  ...
# 8   https://avatars.githubusercontent.com/u/71644535?  ...
# 9   https://avatars.githubusercontent.com/u/71644535?  ...
# 10  https://avatars.githubusercontent.com/u/71644535?  ...
# 11  https://avatars.githubusercontent.com/u/71644535?  ...
# 12  https://avatars.githubusercontent.com/u/71644535?  ...
# 13  https://avatars.githubusercontent.com/u/71644535?  ...
# 14  https://avatars.githubusercontent.com/u/71644535?  ...
# 15  https://avatars.githubusercontent.com/u/71644535?  ...
# 16  https://avatars.githubusercontent.com/u/71644535?  ...
# 17  https://avatars.githubusercontent.com/u/71644535?  ...
# 18  https://avatars.githubusercontent.com/u/71644535?  ...
# 19  https://avatars.githubusercontent.com/u/71644535?  ...
# 20  https://avatars.githubusercontent.com/u/71644535?  ...
# 21  https://avatars.githubusercontent.com/u/71644535?  ...
# 22  https://avatars.githubusercontent.com/u/71644535?  ...
# 23  https://avatars.githubusercontent.com/u/71644535?  ...
# 24  https://avatars.githubusercontent.com/u/71644535?  ...
# 25  https://avatars.githubusercontent.com/u/71644535?  ...
# 26  https://avatars.githubusercontent.com/u/71644535?  ...
# 27  https://avatars.githubusercontent.com/u/71644535?  ...
# 28  https://avatars.githubusercontent.com/u/71644535?  ...
# 29  https://avatars.githubusercontent.com/u/71644535?  ...
#
#     payload.distinct_size      payload.ref  \
# 0                       1  refs/heads/main
# 1                       1  refs/heads/main
# 2                       1  refs/heads/main
# 3                       1  refs/heads/main
# 4                       1  refs/heads/main
# 5                       1  refs/heads/main
# 6                       1  refs/heads/main
# 7                       1  refs/heads/main
# 8                       1  refs/heads/main
# 9                       1  refs/heads/main
# 10                      1  refs/heads/main
# 11                      1  refs/heads/main
# 12                      1  refs/heads/main
# 13                      1  refs/heads/main
# 14                      1  refs/heads/main
# 15                      1  refs/heads/main
# 16                      1  refs/heads/main
# 17                      1  refs/heads/main
# 18                      1  refs/heads/main
# 19                      1  refs/heads/main
# 20                      1  refs/heads/main
# 21                      1  refs/heads/main
# 22                      1  refs/heads/main
# 23                      1  refs/heads/main
# 24                      1  refs/heads/main
# 25                      1  refs/heads/main
# 26                      1  refs/heads/main
# 27                      1  refs/heads/main
# 28                      1  refs/heads/main
# 29                      1  refs/heads/main
#
#                                 payload.head  \
# 0   e6ba7d390d0c21955480d27d5db8d32fc12cfa13
# 1   a27a9e1be7e17974d4b9d51868286edf02f894f6
# 2   28d3a53f3f017702854f2989c305f7e28d8f17f7
# 3   327ef166f61253c20e1ddbd35662fb55fd1f04e6
# 4   b5bf4834025c9a5eadd31e422991ce94775ba740
# 5   0caff9d6eadf728aad8cb9a6e86e0ba563c9f28c
# 6   834fecef75d7fa10d82dbc37d77c7df039beada5
# 7   7b063e8e2a8d41ddaec44bef67cfd52f16ae0da6
# 8   d0cbb9fcd58c20883282f7782af49e245a7e3d74
# 9   0c204b99738f41dec31d4a8cb47c7262640e25ad
# 10  61c93c17e183bd7e4d16ccf4243efecac77f5edf
# 11  051688c41cc171db77fbb37010ee2ceedabf12e5
# 12  78babfe0a38f2aace6b40e990f2503ecb864707e
# 13  1fe8bfb6375df593ee94de7d0f26f5c6962f02c0
# 14  ae7dde404309f8edbe9c2ae6ac46940110e5106b
# 15  4b54bf1f67ca68132cd34a5133240adddb14c7d0
# 16  e5a2ffff52c4ecf267e8e9f335b8e638f9cfa7da
# 17  4550a1099521119d7cabc00c602201d038ed0067
# 18  67096375885c8a09c5a04ec530628addbcef40e3
# 19  98702d38d2daf1015bfb328ea32f8ad2b1a9066d
# 20  b395f1b73277c76edd60a4155ae0abe4b10c5efd
# 21  c718acdbf5f51fff62619db5f2e63e7ca621904e
# 22  8a576c71899483232f0a2d652685b791ca58a32d
# 23  f0ecd8b33b6155ccf07a2024fcc92adf0e67c723
# 24  e3a23d3d9fedeb30ab2da59ae845cfec639a4ba1
# 25  d75f1fd6e00c4f8cd94de86fa9664a6b816afe74
# 26  4bdd4e0221d5408344b69ef56452b98f2807b33f
# 27  0fbea532181ed3c23144e91783ab820b8574a0a7
# 28  d9ccdf8b5195ab2a28a2f87e0bb9e8fd14826b99
# 29  31a5a0b257fb358af3ef8098f85e36c9eab6c65e
#
#                               payload.before  \
# 0   a27a9e1be7e17974d4b9d51868286edf02f894f6
# 1   0caff9d6eadf728aad8cb9a6e86e0ba563c9f28c
# 2   327ef166f61253c20e1ddbd35662fb55fd1f04e6
# 3   b5bf4834025c9a5eadd31e422991ce94775ba740
# 4   192415f4cd0176c16cb6f55aab988e41a95481d5
# 5   834fecef75d7fa10d82dbc37d77c7df039beada5
# 6   7b063e8e2a8d41ddaec44bef67cfd52f16ae0da6
# 7   d0cbb9fcd58c20883282f7782af49e245a7e3d74
# 8   0c204b99738f41dec31d4a8cb47c7262640e25ad
# 9   61c93c17e183bd7e4d16ccf4243efecac77f5edf
# 10  051688c41cc171db77fbb37010ee2ceedabf12e5
# 11  78babfe0a38f2aace6b40e990f2503ecb864707e
# 12  1fe8bfb6375df593ee94de7d0f26f5c6962f02c0
# 13  ae7dde404309f8edbe9c2ae6ac46940110e5106b
# 14  4b54bf1f67ca68132cd34a5133240adddb14c7d0
# 15  e5a2ffff52c4ecf267e8e9f335b8e638f9cfa7da
# 16  4550a1099521119d7cabc00c602201d038ed0067
# 17  67096375885c8a09c5a04ec530628addbcef40e3
# 18  98702d38d2daf1015bfb328ea32f8ad2b1a9066d
# 19  b395f1b73277c76edd60a4155ae0abe4b10c5efd
# 20  c718acdbf5f51fff62619db5f2e63e7ca621904e
# 21  8a576c71899483232f0a2d652685b791ca58a32d
# 22  f0ecd8b33b6155ccf07a2024fcc92adf0e67c723
# 23  e3a23d3d9fedeb30ab2da59ae845cfec639a4ba1
# 24  d75f1fd6e00c4f8cd94de86fa9664a6b816afe74
# 25  4bdd4e0221d5408344b69ef56452b98f2807b33f
# 26  0fbea532181ed3c23144e91783ab820b8574a0a7
# 27  d9ccdf8b5195ab2a28a2f87e0bb9e8fd14826b99
# 28  31a5a0b257fb358af3ef8098f85e36c9eab6c65e
# 29  5e569670a146e0e295c82ca8c099f7770cfb6529
#
#                                       payload.commits    org.id  \
# 0   [{'sha': 'e6ba7d390d0c21955480d27d5db8d32fc12c...  72746426
# 1   [{'sha': 'a27a9e1be7e17974d4b9d51868286edf02f8...  72746426
# 2   [{'sha': '28d3a53f3f017702854f2989c305f7e28d8f...  72746426
# 3   [{'sha': '327ef166f61253c20e1ddbd35662fb55fd1f...  72746426
# 4   [{'sha': 'b5bf4834025c9a5eadd31e422991ce94775b...  72746426
# 5   [{'sha': '0caff9d6eadf728aad8cb9a6e86e0ba563c9...  72746426
# 6   [{'sha': '834fecef75d7fa10d82dbc37d77c7df039be...  72746426
# 7   [{'sha': '7b063e8e2a8d41ddaec44bef67cfd52f16ae...  72746426
# 8   [{'sha': 'd0cbb9fcd58c20883282f7782af49e245a7e...  72746426
# 9   [{'sha': '0c204b99738f41dec31d4a8cb47c7262640e...  72746426
# 10  [{'sha': '61c93c17e183bd7e4d16ccf4243efecac77f...  72746426
# 11  [{'sha': '051688c41cc171db77fbb37010ee2ceedabf...  72746426
# 12  [{'sha': '78babfe0a38f2aace6b40e990f2503ecb864...  72746426
# 13  [{'sha': '1fe8bfb6375df593ee94de7d0f26f5c6962f...  72746426
# 14  [{'sha': 'ae7dde404309f8edbe9c2ae6ac46940110e5...  72746426
# 15  [{'sha': '4b54bf1f67ca68132cd34a5133240adddb14...  72746426
# 16  [{'sha': 'e5a2ffff52c4ecf267e8e9f335b8e638f9cf...  72746426
# 17  [{'sha': '4550a1099521119d7cabc00c602201d038ed...  72746426
# 18  [{'sha': '67096375885c8a09c5a04ec530628addbcef...  72746426
# 19  [{'sha': '98702d38d2daf1015bfb328ea32f8ad2b1a9...  72746426
# 20  [{'sha': 'b395f1b73277c76edd60a4155ae0abe4b10c...  72746426
# 21  [{'sha': 'c718acdbf5f51fff62619db5f2e63e7ca621...  72746426
# 22  [{'sha': '8a576c71899483232f0a2d652685b791ca58...  72746426
# 23  [{'sha': 'f0ecd8b33b6155ccf07a2024fcc92adf0e67...  72746426
# 24  [{'sha': 'e3a23d3d9fedeb30ab2da59ae845cfec639a...  72746426
# 25  [{'sha': 'd75f1fd6e00c4f8cd94de86fa9664a6b816a...  72746426
# 26  [{'sha': '4bdd4e0221d5408344b69ef56452b98f2807...  72746426
# 27  [{'sha': '0fbea532181ed3c23144e91783ab820b8574...  72746426
# 28  [{'sha': 'd9ccdf8b5195ab2a28a2f87e0bb9e8fd1482...  72746426
# 29  [{'sha': '31a5a0b257fb358af3ef8098f85e36c9eab6...  72746426
#
#                     org.login org.gravatar_id  \
# 0   student-IH-labs-and-stuff
# 1   student-IH-labs-and-stuff
# 2   student-IH-labs-and-stuff
# 3   student-IH-labs-and-stuff
# 4   student-IH-labs-and-stuff
# 5   student-IH-labs-and-stuff
# 6   student-IH-labs-and-stuff
# 7   student-IH-labs-and-stuff
# 8   student-IH-labs-and-stuff
# 9   student-IH-labs-and-stuff
# 10  student-IH-labs-and-stuff
# 11  student-IH-labs-and-stuff
# 12  student-IH-labs-and-stuff
# 13  student-IH-labs-and-stuff
# 14  student-IH-labs-and-stuff
# 15  student-IH-labs-and-stuff
# 16  student-IH-labs-and-stuff
# 17  student-IH-labs-and-stuff
# 18  student-IH-labs-and-stuff
# 19  student-IH-labs-and-stuff
# 20  student-IH-labs-and-stuff
# 21  student-IH-labs-and-stuff
# 22  student-IH-labs-and-stuff
# 23  student-IH-labs-and-stuff
# 24  student-IH-labs-and-stuff
# 25  student-IH-labs-and-stuff
# 26  student-IH-labs-and-stuff
# 27  student-IH-labs-and-stuff
# 28  student-IH-labs-and-stuff
# 29  student-IH-labs-and-stuff
#
#                                               org.url  \
# 0   https://api.github.com/orgs/student-IH-labs-an...
# 1   https://api.github.com/orgs/student-IH-labs-an...
# 2   https://api.github.com/orgs/student-IH-labs-an...
# 3   https://api.github.com/orgs/student-IH-labs-an...
# 4   https://api.github.com/orgs/student-IH-labs-an...
# 5   https://api.github.com/orgs/student-IH-labs-an...
# 6   https://api.github.com/orgs/student-IH-labs-an...
# 7   https://api.github.com/orgs/student-IH-labs-an...
# 8   https://api.github.com/orgs/student-IH-labs-an...
# 9   https://api.github.com/orgs/student-IH-labs-an...
# 10  https://api.github.com/orgs/student-IH-labs-an...
# 11  https://api.github.com/orgs/student-IH-labs-an...
# 12  https://api.github.com/orgs/student-IH-labs-an...
# 13  https://api.github.com/orgs/student-IH-labs-an...
# 14  https://api.github.com/orgs/student-IH-labs-an...
# 15  https://api.github.com/orgs/student-IH-labs-an...
# 16  https://api.github.com/orgs/student-IH-labs-an...
# 17  https://api.github.com/orgs/student-IH-labs-an...
# 18  https://api.github.com/orgs/student-IH-labs-an...
# 19  https://api.github.com/orgs/student-IH-labs-an...
# 20  https://api.github.com/orgs/student-IH-labs-an...
# 21  https://api.github.com/orgs/student-IH-labs-an...
# 22  https://api.github.com/orgs/student-IH-labs-an...
# 23  https://api.github.com/orgs/student-IH-labs-an...
# 24  https://api.github.com/orgs/student-IH-labs-an...
# 25  https://api.github.com/orgs/student-IH-labs-an...
# 26  https://api.github.com/orgs/student-IH-labs-an...
# 27  https://api.github.com/orgs/student-IH-labs-an...
# 28  https://api.github.com/orgs/student-IH-labs-an...
# 29  https://api.github.com/orgs/student-IH-labs-an...
#
#                                        org.avatar_url
# 0   https://avatars.githubusercontent.com/u/72746426?
# 1   https://avatars.githubusercontent.com/u/72746426?
# 2   https://avatars.githubusercontent.com/u/72746426?
# 3   https://avatars.githubusercontent.com/u/72746426?
# 4   https://avatars.githubusercontent.com/u/72746426?
# 5   https://avatars.githubusercontent.com/u/72746426?
# 6   https://avatars.githubusercontent.com/u/72746426?
# 7   https://avatars.githubusercontent.com/u/72746426?
# 8   https://avatars.githubusercontent.com/u/72746426?
# 9   https://avatars.githubusercontent.com/u/72746426?
# 10  https://avatars.githubusercontent.com/u/72746426?
# 11  https://avatars.githubusercontent.com/u/72746426?
# 12  https://avatars.githubusercontent.com/u/72746426?
# 13  https://avatars.githubusercontent.com/u/72746426?
# 14  https://avatars.githubusercontent.com/u/72746426?
# 15  https://avatars.githubusercontent.com/u/72746426?
# 16  https://avatars.githubusercontent.com/u/72746426?
# 17  https://avatars.githubusercontent.com/u/72746426?
# 18  https://avatars.githubusercontent.com/u/72746426?
# 19  https://avatars.githubusercontent.com/u/72746426?
# 20  https://avatars.githubusercontent.com/u/72746426?
# 21  https://avatars.githubusercontent.com/u/72746426?
# 22  https://avatars.githubusercontent.com/u/72746426?
# 23  https://avatars.githubusercontent.com/u/72746426?
# 24  https://avatars.githubusercontent.com/u/72746426?
# 25  https://avatars.githubusercontent.com/u/72746426?
# 26  https://avatars.githubusercontent.com/u/72746426?
# 27  https://avatars.githubusercontent.com/u/72746426?
# 28  https://avatars.githubusercontent.com/u/72746426?
# 29  https://avatars.githubusercontent.com/u/72746426?
#
# [30 rows x 25 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response=requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1626188585,
#  'iss_position': {'latitude': '38.3525', 'longitude': '-164.3160'}}

# %%
# when was the last time it was over your house?
coordinates={"lat":52.08486, "lon":-0.46807, "n":10}
response = requests.get("http://api.open-notify.org/iss-pass.json",params=coordinates)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1626189009,
#   'latitude': 52.08486,
#   'longitude': -0.46807,
#   'passes': 10},
#  'response': [{'duration': 524, 'risetime': 1626209565},
#   {'duration': 641, 'risetime': 1626215274},
#   {'duration': 657, 'risetime': 1626221066},
#   {'duration': 653, 'risetime': 1626226874},
#   {'duration': 603, 'risetime': 1626232685},
#   {'duration': 325, 'risetime': 1626238571},
#   {'duration': 453, 'risetime': 1626293182},
#   {'duration': 628, 'risetime': 1626298852},
#   {'duration': 656, 'risetime': 1626304632},
#   {'duration': 656, 'risetime': 1626310439}]}

# %%
#find out the date and time from the timestamp
from datetime import datetime
datetime.fromtimestamp(1626189009)
# Out:
# datetime.datetime(2021, 7, 13, 17, 10, 9)

# %%
pd.to_datetime(1626310439, unit="s")
# Out:
# Timestamp('2021-07-15 00:53:59')

# %% [markdown]
# ## OpenWeatherMap API
#
# A nice person wrote a Python wrapper, which can be found here: https://github.com/csparpa/pyowm
#
# `import sys
# !{sys.executable} -m pip install pyowm`

# %% [markdown]
# Create an account here: https://home.openweathermap.org/users/sign_up
#
# Then Sign in and go to the "Keys" tab.

# %%
#from pyowm import OWM

# %%
#create owm key 
OWM_key="7721c39fc555a1ad9edcdf327ad5385a"

# %%
response=requests.get("http://api.openweathermap.org/data/2.5/weather?q=Bedford,GB&units=metric&appid="+OWM_key)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'coord': {'lon': -0.4663, 'lat': 52.1346},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 20.15,
#   'feels_like': 20.13,
#   'temp_min': 17.6,
#   'temp_max': 23.71,
#   'pressure': 1016,
#   'humidity': 73},
#  'visibility': 10000,
#  'wind': {'speed': 4.63, 'deg': 340},
#  'clouds': {'all': 20},
#  'dt': 1626190214,
#  'sys': {'type': 1,
#   'id': 1454,
#   'country': 'GB',
#   'sunrise': 1626148604,
#   'sunset': 1626207485},
#  'timezone': 3600,
#  'id': 2656046,
#  'name': 'Bedford',
#  'cod': 200}

# %%
from datetime import timezone
dt = datetime(2021, 6, 13)
timestamp = dt.replace(tzinfo=timezone.utc).timestamp()
print(timestamp)
# Out:
# 1623542400.0

# %%
pretty_json=json.loads(response.text)
print(json.dumps(pretty_json, indent=2))

# https://pypi.org/project/flatten-json/ - another option
# Out:
# {
#   "coord": {
#     "lon": -0.4663,
#     "lat": 52.1346
#   },
#   "weather": [
#     {
#       "id": 801,
#       "main": "Clouds",
#       "description": "few clouds",
#       "icon": "02d"
#     }
#   ],
#   "base": "stations",
#   "main": {
#     "temp": 20.15,
#     "feels_like": 20.13,
#     "temp_min": 17.6,
#     "temp_max": 23.71,
#     "pressure": 1016,
#     "humidity": 73
#   },
#   "visibility": 10000,
#   "wind": {
#     "speed": 4.63,
#     "deg": 340
#   },
#   "clouds": {
#     "all": 20
#   },
#   "dt": 1626190214,
#   "sys": {
#     "type": 1,
#     "id": 1454,
#     "country": "GB",
#     "sunrise": 1626148604,
#     "sunset": 1626207485
#   },
#   "timezone": 3600,
#   "id": 2656046,
#   "name": "Bedford",
#   "cod": 200
# }

# %%
# Search for current weather in Bedford and get details

# %%
# Check the sunset time today in Barcelona or Berlin

# %% [markdown]
# ### Sky scanner API
#
# Create an account at RapidAPI and "subscribe" to the sky scanner API: https://rapidapi.com/skyscanner/api/skyscanner-flight-search

# %%
# use RapidAPI to create the request

# %%
# passing headers and parameters to the request just assembles an url:

# %% [markdown]
# To know the parameters we need to be able to call information properly from an API we should look first at its documentation. From the documentation, how would you query the prices for the flights from San Francisco to New York City on 2020/12/12?
