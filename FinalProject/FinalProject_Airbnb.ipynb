# %%
import pandas as pd

# %%
df = pd.read_csv (r'airbnb_1_2008-7_2021.csv')
df.head ()
# Out:
#         Date         Type Confirmation Code Start Date  Nights          Guest  \
# 0   7/4/2021       Payout               NaN        NaN     NaN            NaN
# 1   7/4/2021  Reservation        HMC5RNHHA5   6/3/2021    32.0  Vanessa Lexau
# 2   7/4/2021       Payout               NaN        NaN     NaN            NaN
# 3   7/4/2021  Reservation        HMC5RNHHA5   6/3/2021    32.0  Vanessa Lexau
# 4  6/20/2021       Payout               NaN        NaN     NaN            NaN
#
#                                       Listing                      Details  \
# 0                                         NaN  Transfer to •••••7868 (EUR)
# 1  Duerme en una cabaña en medio de la ciudad                          NaN
# 2                                         NaN  Transfer to •••••4597 (EUR)
# 3  Duerme en una cabaña en medio de la ciudad                          NaN
# 4                                         NaN  Transfer to •••••4597 (EUR)
#
# ...

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               887 non-null    object
#  1   Type               887 non-null    object
#  2   Confirmation Code  475 non-null    object
#  3   Start Date         475 non-null    object
#  4   Nights             475 non-null    float64
#  5   Guest              475 non-null    object
#  6   Listing            475 non-null    object
#  7   Details            453 non-null    object
#  8   Reference          0 non-null      float64
#  9   Currency           887 non-null    object
#  10  Amount             476 non-null    float64
#  11  Paid Out           411 non-null    float64
#  12  Host Fee           399 non-null    float64
#  13  Cleaning Fee       399 non-null    float64
#  14  Linens fee         77 non-null     float64
# dtypes: float64(7), object(8)
# ...
