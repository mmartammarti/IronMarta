# %% [markdown]
# #### Lab tasks - complete tasks 1,2,3 before submitting the notebook via your student portal :
#
# 1) In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue. Here is an [example](https://www.theverge.com/2018/1/12/16882408/google-racist-gorillas-photo-recognition-algorithm-ai) if you are not sure what to look for.

# %% [markdown]
# #### My Opinion

# %% [markdown]
# I feel its trully scary and dangerous as a human race that we use technology to chase by ethnicity. Its beyond ethics.

# %%
https://www.nature.com/articles/d41586-020-03187-3

# %% [markdown]
# 2) use the [https://vision-explorer.allenai.org/text_to_image_generation](https://vision-explorer.allenai.org/text_to_image_generation) to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %%
# %matplotlib inline
from IPython.display import Image
Image('my_image.png')

# %% [markdown]
# Image evaluation: I can imagine a toulipes bouquet in the image... But definately not getting the 'Home Office' theme touch..

# %% [markdown]
# 3) read this [blog article](https://thedatafrog.com/en/articles/dogs-vs-cats/). Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.
#
# -Specifically, what did the coder have to do to PROCESS the images in the cat v dogs dataset to enable the image classification method to be accurate

# %% [markdown]
# In order to be able to get a trained model able to separate dog images from cat ones, the author followed the following steps:
#
# 1. listed the content of the trained directory (ls train)
# 2. she organized images with keras

# %% [markdown]
# mkdir cats
# mkdir dogs
# find train -name 'dog.*' -exec mv {} dogs/ \;
# find train -name 'cat.*' -exec mv {} cats/ \;

# %% [markdown]
# 3. initialization:

# %%
# define and move to dataset directory
datasetdir = '/data2/cbernet/maldives/dogs_vs_cats'
import os
os.chdir(datasetdir)

# import the needed packages
import matplotlib.pyplot as plt
import matplotlib.image as img
from tensorflow import keras
# shortcut to the ImageDataGenerator class
ImageDataGenerator = keras.preprocessing.image.ImageDataGenerator

# %% [markdown]
# 4. plot the first image from each directory (for example:)

# %%
plt.subplot(1,2,1)
plt.imshow(img.imread('cats/cat.0.jpg'))
plt.subplot(1,2,2)
plt.imshow(img.imread('dogs/dog.0.jpg'))

# %% [markdown]
# 5. then she did some data cleaning in order to erase images which were not pictures of the animal.
