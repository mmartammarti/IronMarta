# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# ### json response

# %%
# install json on python if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe

# %%
data=pd.DataFrame.from_dict(results)

# %%
data
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/users/mmartammarti/events/public')
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': '17145943936',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7512094479,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '546014f494c0c17d534fc3d49e3246cdb8bf5ad8',
#    'before': 'cfcdcbf1d6baedaf1dec948d57575842583e2cfc',
#    'commits': [{'sha': '546014f494c0c17d534fc3d49e3246cdb8bf5ad8',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'music recommendations Lab',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/546014f494c0c17d534fc3d49e3246cdb8bf5ad8'}]},
#   'public': True,
#   'created_at': '2021-07-13T14:36:37Z'},
#  {'id': '17129882673',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7504569977,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cfcdcbf1d6baedaf1dec948d57575842583e2cfc',
#    'before': '59b54f8f787310405e77cb8ee5971d78582af014',
#    'commits': [{'sha': 'cfcdcbf1d6baedaf1dec948d57575842583e2cfc',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'web scrapping',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/cfcdcbf1d6baedaf1dec948d57575842583e2cfc'}]},
#   'public': True,
#   'created_at': '2021-07-12T16:21:58Z'},
#  {'id': '17129862816',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7504560918,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '59b54f8f787310405e77cb8ee5971d78582af014',
#    'before': '439e3251758c0d1690a86ad18f193ede3b8eef04',
#    'commits': [{'sha': '59b54f8f787310405e77cb8ee5971d78582af014',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'todays Labs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/59b54f8f787310405e77cb8ee5971d78582af014'}]},
#   'public': True,
#   'created_at': '2021-07-12T16:20:35Z'},
#  {'id': '17042914238',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7460580442,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '439e3251758c0d1690a86ad18f193ede3b8eef04',
#    'before': '5304b249202de7674f045b89daf717fff141a267',
#    'commits': [{'sha': '439e3251758c0d1690a86ad18f193ede3b8eef04',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'today',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/439e3251758c0d1690a86ad18f193ede3b8eef04'}]},
#   'public': True,
#   'created_at': '2021-07-05T15:43:28Z'},
#  {'id': '17002619604',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7439420512,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5a379f348182e51f1161eb517dde999271716803',
#    'before': '9f78cb5383390582e8b3ae34ecb62722c988043b',
#    'commits': [{'sha': '5a379f348182e51f1161eb517dde999271716803',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\n01072021 last update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/5a379f348182e51f1161eb517dde999271716803'}]},
#   'public': True,
#   'created_at': '2021-07-01T14:12:46Z'},
#  {'id': '17002605377',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7439413884,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9f78cb5383390582e8b3ae34ecb62722c988043b',
#    'before': '5d1031f1db8e242b97616765556d91ce8f887e31',
#    'commits': [{'sha': '9f78cb5383390582e8b3ae34ecb62722c988043b',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\nLast update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/9f78cb5383390582e8b3ae34ecb62722c988043b'}]},
#   'public': True,
#   'created_at': '2021-07-01T14:11:56Z'},
#  {'id': '17002572460',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7439398570,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5d1031f1db8e242b97616765556d91ce8f887e31',
#    'before': '8ec647d54f9daef59ed2a3886d9a12fc9c01bf31',
#    'commits': [{'sha': '5d1031f1db8e242b97616765556d91ce8f887e31',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\nAll set',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/5d1031f1db8e242b97616765556d91ce8f887e31'}]},
#   'public': True,
#   'created_at': '2021-07-01T14:10:01Z'},
#  {'id': '17002505702',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7439367533,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8ec647d54f9daef59ed2a3886d9a12fc9c01bf31',
#    'before': 'a4f63bffd021b4a0f5ccce7989a0145f021a98f0',
#    'commits': [{'sha': '8ec647d54f9daef59ed2a3886d9a12fc9c01bf31',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\nLast commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/8ec647d54f9daef59ed2a3886d9a12fc9c01bf31'}]},
#   'public': True,
#   'created_at': '2021-07-01T14:06:04Z'},
#  {'id': '17002231483',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7439238929,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a4f63bffd021b4a0f5ccce7989a0145f021a98f0',
#    'before': '72de9e6f13c007d81a896ce288fe172c3bc2dab2',
#    'commits': [{'sha': 'a4f63bffd021b4a0f5ccce7989a0145f021a98f0',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\nFinal update to our gitHub Readme for this project!',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/a4f63bffd021b4a0f5ccce7989a0145f021a98f0'}]},
#   'public': True,
#   'created_at': '2021-07-01T13:50:14Z'},
#  {'id': '16991399485',
#   'type': 'MemberEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'member': {'login': 'Damaris0207',
#     'id': 84089705,
#     'node_id': 'MDQ6VXNlcjg0MDg5NzA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/84089705?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Damaris0207',
#     'html_url': 'https://github.com/Damaris0207',
#     'followers_url': 'https://api.github.com/users/Damaris0207/followers',
#     'following_url': 'https://api.github.com/users/Damaris0207/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Damaris0207/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Damaris0207/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Damaris0207/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Damaris0207/orgs',
#     'repos_url': 'https://api.github.com/users/Damaris0207/repos',
#     'events_url': 'https://api.github.com/users/Damaris0207/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Damaris0207/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2021-06-30T21:02:51Z'},
#  {'id': '16988576973',
#   'type': 'PublicEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {},
#   'public': True,
#   'created_at': '2021-06-30T17:13:53Z'},
#  {'id': '16987825626',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7432400401,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '72de9e6f13c007d81a896ce288fe172c3bc2dab2',
#    'before': '73a8223bddd3c5b49ba8fb5a8e0b5d42b5e8cb7e',
#    'commits': [{'sha': '72de9e6f13c007d81a896ce288fe172c3bc2dab2',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\nagain',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/72de9e6f13c007d81a896ce288fe172c3bc2dab2'}]},
#   'public': True,
#   'created_at': '2021-06-30T16:17:31Z'},
#  {'id': '16987802524',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 381053280,
#    'name': 'mmartammarti/CovidInSpanishHospitals2020',
#    'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020'},
#   'payload': {'push_id': 7432390067,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '73a8223bddd3c5b49ba8fb5a8e0b5d42b5e8cb7e',
#    'before': 'a02986de6baf7a452ee887842c4fd978920b93a6',
#    'commits': [{'sha': '73a8223bddd3c5b49ba8fb5a8e0b5d42b5e8cb7e',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update README.md\n\nANother change',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/CovidInSpanishHospitals2020/commits/73a8223bddd3c5b49ba8fb5a8e0b5d42b5e8cb7e'}]},
#   'public': True,
#   'created_at': '2021-06-30T16:15:53Z'},
#  {'id': '16928722015',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7402223537,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5304b249202de7674f045b89daf717fff141a267',
#    'before': 'ed385153b73c1f6463cc7391e0052f6ef57f6454',
#    'commits': [{'sha': '5304b249202de7674f045b89daf717fff141a267',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'day 18 lab update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/5304b249202de7674f045b89daf717fff141a267'}]},
#   'public': True,
#   'created_at': '2021-06-25T16:10:45Z'},
#  {'id': '16928699008',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7402212415,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'ed385153b73c1f6463cc7391e0052f6ef57f6454',
#    'before': '1fc397bd450a8fe4cd8d0c152ab9f352906ac894',
#    'commits': [{'sha': '78926f3eb44984c46a8fb28476d41f813ea6e4d2',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'updating labs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/78926f3eb44984c46a8fb28476d41f813ea6e4d2'},
#     {'sha': 'ed385153b73c1f6463cc7391e0052f6ef57f6454',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'labs update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/ed385153b73c1f6463cc7391e0052f6ef57f6454'}]},
#   'public': True,
#   'created_at': '2021-06-25T16:08:54Z'},
#  {'id': '16928536687',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7402133789,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1fc397bd450a8fe4cd8d0c152ab9f352906ac894',
#    'before': 'ab0478f3198eead49dd2772701e6b0981628ecea',
#    'commits': [{'sha': '1fc397bd450a8fe4cd8d0c152ab9f352906ac894',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': "Create ReadMeLabDay18.md\n\nCan we predict churn in telecomunication companies?\r\n\r\nCreating a ML model and evaluating it's effectiveness.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/1fc397bd450a8fe4cd8d0c152ab9f352906ac894'}]},
#   'public': True,
#   'created_at': '2021-06-25T15:56:22Z'},
#  {'id': '16923816854',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7399839913,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ab0478f3198eead49dd2772701e6b0981628ecea',
#    'before': 'cc971f1775b2fb8bce3fa5f62735acdaa84ab85f',
#    'commits': [{'sha': 'ab0478f3198eead49dd2772701e6b0981628ecea',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Update ReadMe.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/ab0478f3198eead49dd2772701e6b0981628ecea'}]},
#   'public': True,
#   'created_at': '2021-06-25T09:53:45Z'},
#  {'id': '16923781763',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7399822545,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cc971f1775b2fb8bce3fa5f62735acdaa84ab85f',
#    'before': 'bd07c09ec0277b95107ba14f8b0f5c1c012a4bb2',
#    'commits': [{'sha': 'cc971f1775b2fb8bce3fa5f62735acdaa84ab85f',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'ReadMe_LogisticRegressionExplained',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/cc971f1775b2fb8bce3fa5f62735acdaa84ab85f'}]},
#   'public': True,
#   'created_at': '2021-06-25T09:51:01Z'},
#  {'id': '16896823352',
#   'type': 'ForkEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 170851813,
#    'name': 'ta-data-bcn/lab-subsetting-and-descriptive-stats',
#    'url': 'https://api.github.com/repos/ta-data-bcn/lab-subsetting-and-descriptive-stats'},
#   'payload': {'forkee': {'id': 379651704,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzNzk2NTE3MDQ=',
#     'name': 'lab-subsetting-and-descriptive-stats',
#     'full_name': 'mmartammarti/lab-subsetting-and-descriptive-stats',
#     'private': False,
#     'owner': {'login': 'mmartammarti',
#      'id': 30186859,
#      'node_id': 'MDQ6VXNlcjMwMTg2ODU5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mmartammarti',
#      'html_url': 'https://github.com/mmartammarti',
#      'followers_url': 'https://api.github.com/users/mmartammarti/followers',
#      'following_url': 'https://api.github.com/users/mmartammarti/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mmartammarti/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mmartammarti/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mmartammarti/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mmartammarti/orgs',
#      'repos_url': 'https://api.github.com/users/mmartammarti/repos',
#      'events_url': 'https://api.github.com/users/mmartammarti/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mmartammarti/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/mmartammarti/lab-subsetting-and-descriptive-stats',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats',
#     'forks_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/forks',
#     'keys_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/teams',
#     'hooks_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/hooks',
#     'issue_events_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/events',
#     'assignees_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/tags',
#     'blobs_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/languages',
#     'stargazers_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/stargazers',
#     'contributors_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/contributors',
#     'subscribers_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/subscribers',
#     'subscription_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/subscription',
#     'commits_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/merges',
#     'archive_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/downloads',
#     'issues_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/mmartammarti/lab-subsetting-and-descriptive-stats/deployments',
#     'created_at': '2021-06-23T15:36:48Z',
#     'updated_at': '2020-11-16T13:52:39Z',
#     'pushed_at': '2020-11-16T13:52:35Z',
#     'git_url': 'git://github.com/mmartammarti/lab-subsetting-and-descriptive-stats.git',
#     'ssh_url': 'git@github.com:mmartammarti/lab-subsetting-and-descriptive-stats.git',
#     'clone_url': 'https://github.com/mmartammarti/lab-subsetting-and-descriptive-stats.git',
#     'svn_url': 'https://github.com/mmartammarti/lab-subsetting-and-descriptive-stats',
#     'homepage': None,
#     'size': 28815,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-06-23T15:36:49Z'},
#  {'id': '16896545145',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7386310026,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bd07c09ec0277b95107ba14f8b0f5c1c012a4bb2',
#    'before': 'd6c5b36218794db93a88235b8162b625c12ad1ef',
#    'commits': [{'sha': 'bd07c09ec0277b95107ba14f8b0f5c1c012a4bb2',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'day 16 lab improved',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/bd07c09ec0277b95107ba14f8b0f5c1c012a4bb2'}]},
#   'public': True,
#   'created_at': '2021-06-23T15:20:00Z'},
#  {'id': '16896464674',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7386271984,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd6c5b36218794db93a88235b8162b625c12ad1ef',
#    'before': '36af03ed9674dbfb65b5ef98f8a1f805f93b7e46',
#    'commits': [{'sha': 'd6c5b36218794db93a88235b8162b625c12ad1ef',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'SQL and Tableau Lab',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/d6c5b36218794db93a88235b8162b625c12ad1ef'}]},
#   'public': True,
#   'created_at': '2021-06-23T15:15:16Z'},
#  {'id': '16893976347',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372533644,
#    'name': 'mmartammarti/BEES-DAFT-MAY21',
#    'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21'},
#   'payload': {'push_id': 7385090614,
#    'size': 48,
#    'distinct_size': 48,
#    'ref': 'refs/heads/main',
#    'head': '057870c120e35822f812ab1b8b9a35397aca3ac5',
#    'before': '69f47a6142131ab4e77034c566341b77d38f243c',
#    'commits': [{'sha': '98f26c9d44568b7657eb762efb8cde21ee540bfe',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update String_Operations_lab.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/98f26c9d44568b7657eb762efb8cde21ee540bfe'},
#     {'sha': '2745428b6ef6211b7cec0c6654d1a9e14aece770',
#      'author': {'email': '', 'name': 'n1oftheabove'},
#      'message': 'add: python lecture week1 day3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/2745428b6ef6211b7cec0c6654d1a9e14aece770'},
#     {'sha': '6178004a2f45039bee07ae16d1575934cdaded7c',
#      'author': {'email': '', 'name': 'n1oftheabove'},
#      'message': 'mv: day3 week 1 python lecture to unit1 folder',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/6178004a2f45039bee07ae16d1575934cdaded7c'},
#     {'sha': '5e98365cccf8d9e06777ddd7e66219eb19999cf1',
#      'author': {'email': '', 'name': 'n1oftheabove'},
#      'message': 'upload CAR2 lab solutions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/5e98365cccf8d9e06777ddd7e66219eb19999cf1'},
#     {'sha': '551d251a875c2bfcdf731b65fbdfaf4e6b39f721',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Tableau_Filtering.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/551d251a875c2bfcdf731b65fbdfaf4e6b39f721'},
#     {'sha': '984dfb0e7afe4c3902233d33bdd5022086a438fa',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/984dfb0e7afe4c3902233d33bdd5022086a438fa'},
#     {'sha': '519fe5410e17204e64957fedca72eee0f40d3c15',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/519fe5410e17204e64957fedca72eee0f40d3c15'},
#     {'sha': '6f427363875f6afc71ef335a100683701a630ca3',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create time_series_analysis.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/6f427363875f6afc71ef335a100683701a630ca3'},
#     {'sha': 'ca5d4ce22898be8944e01aa618c4ce4a60e06205',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Rename time_series_analysis.md to Tableau-time_series_analysis.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/ca5d4ce22898be8944e01aa618c4ce4a60e06205'},
#     {'sha': 'a345e52ac5ea2a7e599c40999308eeb40cd3de33',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Tableau_simple_charts.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/a345e52ac5ea2a7e599c40999308eeb40cd3de33'},
#     {'sha': '68821b781e7b70f3edb5e4eaeb5fbd06f4a0ef8e',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Tableau_Filtering.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/68821b781e7b70f3edb5e4eaeb5fbd06f4a0ef8e'},
#     {'sha': 'b28f8da50bd0b8aeb44885d9922296780fb81610',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Tableau_Filtering.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/b28f8da50bd0b8aeb44885d9922296780fb81610'},
#     {'sha': 'a76d9d5fa20e93497eb732c3d49c9f39530e79d2',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Tableau-time_series_analysis.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/a76d9d5fa20e93497eb732c3d49c9f39530e79d2'},
#     {'sha': 'f652413ea27aeaae218b9319610902a8973cc5a7',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Tableau_Guided_Stories_easier.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/f652413ea27aeaae218b9319610902a8973cc5a7'},
#     {'sha': 'd79f2de28d5993941dabbe68024cdc229bd40d9b',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/d79f2de28d5993941dabbe68024cdc229bd40d9b'},
#     {'sha': 'e32f33e8ba856de79fdb53532fca74a7396e979c',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/e32f33e8ba856de79fdb53532fca74a7396e979c'},
#     {'sha': '71b1e1133c156f2f80a74a84f99fd4895c5825ea',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Delete Solutions/unit2/day2 directory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/71b1e1133c156f2f80a74a84f99fd4895c5825ea'},
#     {'sha': 'ff5c696d61a6719ab5b21065ee68fdc4f47192a1',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/ff5c696d61a6719ab5b21065ee68fdc4f47192a1'},
#     {'sha': 'd30b124392ef1385cc3eff52beba7ca64b2aa904',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/d30b124392ef1385cc3eff52beba7ca64b2aa904'},
#     {'sha': '78d5c67afd98beca9f8fa4df864de425dd586d42',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/BEES-DAFT-MAY21/commits/78d5c67afd98beca9f8fa4df864de425dd586d42'}]},
#   'public': True,
#   'created_at': '2021-06-23T12:48:28Z'},
#  {'id': '16879966527',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7378294547,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/main',
#    'head': '36af03ed9674dbfb65b5ef98f8a1f805f93b7e46',
#    'before': '4041f8e09b22031ab22bd493a4ea87717aa27eb0',
#    'commits': [{'sha': '922943c0015487d2aefea5ecd0a67f9e67c9e3fb',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': "today's lab",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/922943c0015487d2aefea5ecd0a67f9e67c9e3fb'},
#     {'sha': 'e2a1f4c123899e5ae852177df0a261e39a20717d',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'todays work',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/e2a1f4c123899e5ae852177df0a261e39a20717d'},
#     {'sha': '7a12319476ca559a2bbabdf414d65c777cb8f29b',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'todays work',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/7a12319476ca559a2bbabdf414d65c777cb8f29b'},
#     {'sha': '2be741fec078f3b9661091b355e924db0d93a464',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'todays lab',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/2be741fec078f3b9661091b355e924db0d93a464'},
#     {'sha': 'f89debc59ff8ff46e0c4bde583cf8f1f967c3d39',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'adding todays class and lab',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/f89debc59ff8ff46e0c4bde583cf8f1f967c3d39'},
#     {'sha': '36af03ed9674dbfb65b5ef98f8a1f805f93b7e46',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'marta marti'},
#      'message': 'updating my repo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/36af03ed9674dbfb65b5ef98f8a1f805f93b7e46'}]},
#   'public': True,
#   'created_at': '2021-06-22T15:26:10Z'},
#  {'id': '16824187911',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349316064,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4041f8e09b22031ab22bd493a4ea87717aa27eb0',
#    'before': 'e7f83ff7dc5aae10d1e6ef250452154b36060125',
#    'commits': [{'sha': '4041f8e09b22031ab22bd493a4ea87717aa27eb0',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Todays Lab completed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/4041f8e09b22031ab22bd493a4ea87717aa27eb0'}]},
#   'public': True,
#   'created_at': '2021-06-17T16:18:43Z'},
#  {'id': '16823956504',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349207772,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e7f83ff7dc5aae10d1e6ef250452154b36060125',
#    'before': '5a263d4ae3f0d076dd311142b943085130c83921',
#    'commits': [{'sha': 'e7f83ff7dc5aae10d1e6ef250452154b36060125',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Create ReadMe\n\nOur highlights: \r\nDefined base ideas and columns to tidy up a basic structure.\r\nWe’ve created the specifications_id concept to be able to filter directly by restaurant without the need to check menu by menu (being able to detect restaurants with dishes compatible with vegetarian or food allergy requirement options)  \r\nIn Food Specificcation we changed menu_id for specification_id so we could show all the options specification wise without having to enter all the menus available. \r\nTransaction table possibilities : offering options to the Mkt team such as: coupons for less active users, reward for best customers, etc. detect best performers in both restaurant and menu list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/e7f83ff7dc5aae10d1e6ef250452154b36060125'}]},
#   'public': True,
#   'created_at': '2021-06-17T16:03:19Z'},
#  {'id': '16823866600',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349165512,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5a263d4ae3f0d076dd311142b943085130c83921',
#    'before': '44b7bb7adf9ff119e689186513df7ceaf5ff4c99',
#    'commits': [{'sha': '5a263d4ae3f0d076dd311142b943085130c83921',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Delete cw\n\nnot useful',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/5a263d4ae3f0d076dd311142b943085130c83921'}]},
#   'public': True,
#   'created_at': '2021-06-17T15:57:40Z'},
#  {'id': '16823859170',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349162076,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '44b7bb7adf9ff119e689186513df7ceaf5ff4c99',
#    'before': '4217fb64f9d462377d4cb8bebb5e854ca5d4e6c8',
#    'commits': [{'sha': '44b7bb7adf9ff119e689186513df7ceaf5ff4c99',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Add files via upload\n\nTodays Lab and Team Work',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/44b7bb7adf9ff119e689186513df7ceaf5ff4c99'}]},
#   'public': True,
#   'created_at': '2021-06-17T15:57:11Z'},
#  {'id': '16823847746',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349156686,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4217fb64f9d462377d4cb8bebb5e854ca5d4e6c8',
#    'before': '634b47046eee54489e8d76b0818b6b9417bdeb01',
#    'commits': [{'sha': '4217fb64f9d462377d4cb8bebb5e854ca5d4e6c8',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Dmcklwc\n\nwec',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/4217fb64f9d462377d4cb8bebb5e854ca5d4e6c8'}]},
#   'public': True,
#   'created_at': '2021-06-17T15:56:25Z'},
#  {'id': '16823714103',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349093570,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '634b47046eee54489e8d76b0818b6b9417bdeb01',
#    'before': '2b07dcba6f58ea2b03f620d8e0fdf2edccd31c73',
#    'commits': [{'sha': '634b47046eee54489e8d76b0818b6b9417bdeb01',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': "Delete Day_14_sql directory\n\nI have to add today's labs",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/634b47046eee54489e8d76b0818b6b9417bdeb01'}]},
#   'public': True,
#   'created_at': '2021-06-17T15:47:50Z'},
#  {'id': '16823633476',
#   'type': 'PushEvent',
#   'actor': {'id': 30186859,
#    'login': 'mmartammarti',
#    'display_login': 'mmartammarti',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmartammarti',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30186859?'},
#   'repo': {'id': 372516678,
#    'name': 'mmartammarti/IronMarta',
#    'url': 'https://api.github.com/repos/mmartammarti/IronMarta'},
#   'payload': {'push_id': 7349055446,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2b07dcba6f58ea2b03f620d8e0fdf2edccd31c73',
#    'before': '03c7ba2881f89507729b75c5b4775a2b014e911e',
#    'commits': [{'sha': '2b07dcba6f58ea2b03f620d8e0fdf2edccd31c73',
#      'author': {'email': 'martamartid@icloud.com', 'name': 'martamarti'},
#      'message': 'Create ReadMe\n\nOur highlights: \r\nDefined base ideas and columns to tidy up a basic structure.\r\nWe’ve created the specifications_id concept to be able to filter directly by restaurant without the need to check menu by menu (being able to detect restaurants with dishes compatible with vegetarian or food allergy requirement options)  \r\nIn Food Specificcation we changed menu_id for specification_id so we could show all the options specification wise without having to enter all the menus available. \r\nTransaction table possibilities : offering options to the Mkt team such as: coupons for less active users, reward for best customers, etc. detect best performers in both restaurant and menu list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmartammarti/IronMarta/commits/2b07dcba6f58ea2b03f620d8e0fdf2edccd31c73'}]},
#   'public': True,
#   'created_at': '2021-06-17T15:42:37Z'}]

# %% [markdown]
# pd.DataFrame(response.json())

# %%
#turn the json into a Data Frame

# %%
#unpack the json using  pd.json_normalize()

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.

# Print the status code of the response.

# %%
# when was the last time it was over your house?

# %%
#find out the date and time from the timestamp
from datetime import datetime

# %% [markdown]
# ## OpenWeatherMap API
#
# A nice person wrote a Python wrapper, which can be found here: https://github.com/csparpa/pyowm
#
# `import sys
# !{sys.executable} -m pip install pyowm`

# %% [markdown]
# Create an account here: https://home.openweathermap.org/users/sign_up
#
# Then Sign in and go to the "Keys" tab.

# %%
from pyowm import OWM

# %%
a97538f7c693fda9dc112068fd15c339

# %%
# Search for current weather in Bedford and get details

# %%
# Check the sunset time today in Barcelona or Berlin

# %% [markdown]
# ### Sky scanner API
#
# Create an account at RapidAPI and "subscribe" to the sky scanner API: https://rapidapi.com/skyscanner/api/skyscanner-flight-search

# %%
# use RapidAPI to create the request

# %%
# passing headers and parameters to the request just assembles an url:

# %% [markdown]
# To know the parameters we need to be able to call information properly from an API we should look first at its documentation. From the documentation, how would you query the prices for the flights from San Francisco to New York City on 2020/12/12?
