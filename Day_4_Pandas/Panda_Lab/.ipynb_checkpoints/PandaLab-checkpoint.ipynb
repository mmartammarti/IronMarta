# %% [markdown]
# # Lab | Customer Analysis Round 1

# %% [markdown]
# ##### Remember the process:
#
# <li>Case Study
# <li>Get data
# <li>Cleaning/Wrangling/EDA
# <li>Processing Data
# <li>Modeling
# <li>Validation
# <li>Reporting
#
# ##### Abstract
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 csv files that are provided in the files_for_lab folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# ##### Instructions
# <li> Read the three files into python as dataframes
#
# <li>Show the DataFrame's shape.
#
# <li>Standardize header names.
#
# <li>Rearrange the columns in the dataframe as needed
#
# <li>Concatenate the three dataframes
#
# <li>Which columns are numerical?
#
# <li>Which columns are categorical?
#
# <li>Understand the meaning of all columns
#
# <li>Perform the data cleaning operations mentioned so far in class
#
# Delete the column education and the number of open complaints from the dataframe.
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
# Check for duplicate rows in the data and remove if any.
# Filter out the data for customers who have an income of 0 or less.

# %%
pwd
# Out:
# '/Users/martamarti/ironhack/IronMarta/Day_4_Pandas/Panda_Lab'

# %%
import pandas as pd

# %%
import numpy as np

# %%
file1=pd.read_csv("file1.csv")

# %%
file2=pd.read_csv("file2.csv")

# %%
file3=pd.read_csv("file3.csv")

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.sort_index(axis=1)
# Out:
#      Customer Customer Lifetime Value             Education GENDER   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
# ...

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file1.sort_index(axis=1)
# Out:
#      Customer Customer Lifetime Value             Education GENDER   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
# ...

# %%
file2.sort_index(axis=1)
# Out:
#     Customer Customer Lifetime Value Education GENDER  Income  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# ...

# %%
file3.sort_index(axis=1)
# Out:
#      Customer  Customer Lifetime Value             Education Gender  Income  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
# ...

# %%
file1.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, ST, GENDER, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount]
# Index: []

# %%
cols=[]
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower())
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
cols=[]
for i in range(len(file2.columns)):
    cols.append(file2.columns[i].lower())
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'total claim amount',
#  'policy type',
#  'vehicle class']

# %%
file2.sort_index(axis=1)

# %%
data.columns=cols

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [customer, state, customer lifetime value, education, gender, income, monthly premium auto, number of open complaints, policy type, total claim amount, vehicle class]
# Index: []

# %%
file2.columns = file3.columns
file1.columns = file3.columns

# %%
file3.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %%
cols=[]
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower())
cols
# Out:
# ['customer',
#  'state',
#  'customer lifetime value',
#  'education',
#  'gender',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'total claim amount',
#  'vehicle class']

# %%
 data.dtypes
# Out:
# customer                     object
# state                        object
# customer lifetime value      object
# education                    object
# gender                       object
# income                       object
# monthly premium auto         object
# number of open complaints    object
# policy type                  object
# total claim amount           object
# vehicle class                object
# dtype: object

# %%
file3.shape
# Out:
# (7070, 11)

# %%
data=pd.concat([data,file1],axis=0)

# %%
data=pd.concat([data,file2],axis=0)

# %%
data=pd.concat([data,file3],axis=0)

# %%
data.shape
# Out:
# (21210, 22)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21210 entries, 0 to 21209
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   0 non-null      object
#  1   state                      0 non-null      object
#  2   customer lifetime value    0 non-null      object
#  3   education                  0 non-null      object
#  4   gender                     0 non-null      object
#  5   income                     0 non-null      object
#  6   monthly premium auto       0 non-null      object
#  7   number of open complaints  0 non-null      object
#  8   policy type                0 non-null      object
#  9   total claim amount         0 non-null      object
#  10  vehicle class              0 non-null      object
#  11  Customer                   21210 non-null  object
#  12  State                      21210 non-null  object
# ...

# %%
data['customer lifetime value']=pd.to_numeric(data['customer lifetime value'],errors='coerce')

# %%
data['income']=pd.to_numeric(data['income'],errors='coerce')

# %%
data['monthly premium auto']=pd.to_numeric(data['monthly premium auto'],errors='coerce')

# %%
data['number of open complaints']=pd.to_numeric(data['number of open complaints'],errors='coerce')

# %%
data['total claim amount']=pd.to_numeric(data['total claim amount'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21210 entries, 0 to 21209
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   0 non-null      object
#  1   state                      0 non-null      object
#  2   customer lifetime value    0 non-null      float64
#  3   education                  0 non-null      object
#  4   gender                     0 non-null      object
#  5   income                     0 non-null      float64
#  6   monthly premium auto       0 non-null      float64
#  7   number of open complaints  0 non-null      float64
#  8   policy type                0 non-null      object
#  9   total claim amount         0 non-null      float64
#  10  vehicle class              0 non-null      object
#  11  Customer                   21210 non-null  object
#  12  State                      21210 non-null  object
# ...
